# %% [markdown]
# ## Julian Date

# %%
D=float(input("Day:"))
M=int(input("Month:"))
Y=int(input("Year:"))
JD = 367*Y -7*(Y+(M+9)/12)/4 - 3*((Y+(M-9)/7)/100 + 1)/4 + (275*M)/9 + D + 1721029-0.5
print(f"The Julian Date is: ", JD)
# Out:
# Day: 4
# Month: 1
# Year: 1700
# The Julian Date is:  2341973.1057936507

# %% [markdown]
# https://jupyterhub.astro.rug.nl/user/vcalvo/files/PROGNUM/Task2/este.pdf?_xsrf=
