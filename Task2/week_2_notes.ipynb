# %% [markdown]
# # Python sequence basics

# %% [markdown]
# # 1.Processing a sequence of numbers
# A **list** is a seuquence that can store any Python object. It can mix integers, floating point numbers and strings.
# Starting with an empty list ``[]`` & use a special function of lists (called a method) to append values:
